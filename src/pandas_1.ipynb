# %%
import pandas as pd

data = pd.read_csv("../data/raw/empleados_sinteticos.csv", index_col="id")
df = pd.read_csv("../data/raw/dataset.csv", index_col="id")

# %%
data
# Out:
#                  nombre fecha_ingreso  edad sexo fecha_retiro        cargo
# id
# 1          Trabajador_1    2025-06-03    33    M          NaN    Ingeniero
# 2          Trabajador_2    2023-01-04    38    M   2025-02-27     Director
# 3          Trabajador_3    2025-08-04    32    F          NaN    Consultor
# 4          Trabajador_4    2024-07-13    60    M          NaN      Gerente
# 5          Trabajador_5    2024-05-05    21    M   2024-11-09    Consultor
# ...                 ...           ...   ...  ...          ...          ...
# 49996  Trabajador_49996    2021-08-26    18    F   2022-12-17     Auxiliar
# 49997  Trabajador_49997    2021-12-15    61    M   2022-05-23     Director
# 49998  Trabajador_49998    2024-04-06    44    F          NaN  Coordinador
# 49999  Trabajador_49999    2022-11-22    63    M   2024-10-10     Analista
# 50000  Trabajador_50000    2024-01-12    40    F   2025-03-05  Coordinador
#
# [50000 rows x 6 columns]

# %%
data.describe()
# Out:
#                edad
# count  50000.000000
# mean      41.466300
# std       13.842758
# min       18.000000
# 25%       29.000000
# 50%       41.000000
# 75%       53.000000
# max       65.000000

# %%
df_limpios = df.dropna()
df_limpios
# Out:
#                                                 full_text  favorites  \
# id
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# 183733                           Programming is the best!      467.0
# 183734                             I cannot believe this!       50.0
# 183735                             Buy this product NOW!!      418.0
# ...

# %%
# df_filtrado = df.fillna(0)
df_filtrado = df.fillna({"retweets":0, "mentions":-1})
df_filtrado
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183728  Thank you guess how did I feel somewhat offend...        NaN
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# ...

# %%
df[["full_text", "favorites"]]
# Out:
#                                                 full_text  favorites
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183728  Thank you guess how did I feel somewhat offend...        NaN
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# 183733                           Programming is the best!      467.0
# ...

# %%
df.iloc[0]
# df.iloc[0:3]
# df.iloc[[0, 2, 3]]
df.loc[[183745, 183723]]
# Out:
#                                            full_text  favorites  retweets  \
# id
# 183745     There is nothing better than programming!      424.0     110.0
# 183723  Today we have reached US$6.55 Billion TT$44…      190.0     123.0
#
#         mentions country         user  followers  followees
# id
# 183745      29.0  BRASIL   lucasperes       82.0        351
# 183723       6.0  MEXICO  pedrojuarez       12.0        129

# %%
df.loc[[183745, 183723], ["favorites"]]
# Out:
#         favorites
# id
# 183745      424.0
# 183723      190.0

# %%
# df[df["favorites"] > 400]
# df[(df["favorites"] > 400 ) & (df["mentions"] > 20)]
df[df["full_text"].str.contains("Programming")]
# Out:
#                           full_text  favorites  retweets  mentions  country  \
# id
# 183733     Programming is the best!      467.0      69.0      10.0  ECUADOR
# 183740  Programming is a hot topic!      133.0     145.0      15.0   BRASIL
# 183741      Programming? i love it!       92.0     146.0       1.0  ECUADOR
#
#                  user  followers  followees
# id
# 183733  leonardokuffo      389.0        258
# 183740     lucasperes       82.0        351
# 183741   galocastillo      332.0        378

# %%
import random
def calcularGanancias(retweets):
    return retweets * random.randint(3, 5)

df_filtrado["ganancias"] = df["retweets"].apply(calcularGanancias)

def popularidad(fila):
    resultado = fila['followees']/fila['followers']
    return resultado

df_filtrado['popularidad'] = df.apply(popularidad, axis=1)
df
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183728  Thank you guess how did I feel somewhat offend...        NaN
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# ...

# %%
df_filtrado.groupby("country").mean(numeric_only=True)
# Out:
#           favorites   retweets   mentions  followers    followees   ganancias  \
# country
# BRASIL   339.909091  91.272727  17.727273    616.600  1889.363636  344.000000
# ECUADOR  186.375000  56.750000  11.875000    360.500   318.000000  247.571429
# MEXICO   294.857143  77.750000  13.750000     15.375  1101.000000  291.375000
#
#          popularidad
# country
# BRASIL      3.708644
# ECUADOR     0.900897
# MEXICO     55.308036

# %%
df_filtrado.groupby("country").agg({
    "followers": 'sum',
    "mentions": 'mean',
    "retweets": 'max'
})
# Out:
#          followers   mentions  retweets
# country
# BRASIL      6166.0  17.727273     145.0
# ECUADOR     2884.0  11.875000     146.0
# MEXICO       123.0  13.750000     130.0
